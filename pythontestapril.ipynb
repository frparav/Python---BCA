# %% [markdown]
# ## Section A — Very Easy Coding Questions

# %% [markdown]
# Ques - 1: Required Code:

# %%
class Student:
    school_name = "UPES"
    def __init__(self,name,age):
        self.name = name
        self.age = age
student1 = Student("Aman", 20)
student2 = Student("Riya", 22)
print(f"School (via Student 1): {student1.school_name}")
print(f"School (via Student 2): {student2.school_name}")
print(f"Student 1: Name={student1.name}, Age={student1.age}")
print(f"Student 2: Name={student2.name}, Age={student2.age}")
# Out:
# School (via Student 1): UPES
# School (via Student 2): UPES
# Student 1: Name=Aman, Age=20
# Student 2: Name=Riya, Age=22

# %% [markdown]
# Ques 2 : Required Code:

# %%
class Employee:
    company = "ABC Ltd"

    def __init__(self,name,salary):
        self.name = name
        self.salary = salary

    def show_details(self):
        print(f"Name: {self.name},  Salary: {self.salary},  Company: {Employee.company}")
    
    @classmethod
    def change_company(cls, new_name):
        cls.company = new_name

emp1 = Employee("Aman", 50000)
emp2 = Employee("Riya", 60000)     

print("Before company change:")
emp1.show_details()
emp2.show_details()

Employee.change_company("XYZ Pvt Ltd")

print("\nAfter company change:")
emp1.show_details()
emp2.show_details()
# Out:
# Before company change:
# Name: Aman,  Salary: 50000,  Company: ABC Ltd
# Name: Riya,  Salary: 60000,  Company: ABC Ltd
#
# After company change:
# Name: Aman,  Salary: 50000,  Company: XYZ Pvt Ltd
# Name: Riya,  Salary: 60000,  Company: XYZ Pvt Ltd

# %% [markdown]
# Ques 3: Required Code

# %%
class MathHelper:

    @staticmethod
    def is_even(num):
        return num % 2 == 0


# Testing
print(MathHelper.is_even(8))   # True
print(MathHelper.is_even(11))  # False
# Out:
# True
# False

# %% [markdown]
# # Section B — Easy to Moderate Coding Questions

# %% [markdown]
# Ques - 4 : Required Code

# %%
class BankAccount:

    def __init__(self, name, balance=0):
        self.name = name          # public variable
        self.__balance = balance  # private variable

    def deposit(self, amount):
        self.__balance += amount
        print(f"{amount} deposited.")

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount
            print(f"{amount} withdrawn.")
        else:
            print("Insufficient balance")

    def show_balance(self):
        print(f"Balance: {self.__balance}")


# Testing
acc = BankAccount("Aman", 1000)

acc.show_balance()     # Initial balance
acc.deposit(500)       # Deposit
acc.show_balance()
acc.withdraw(300)      # Valid withdraw
acc.show_balance()
acc.withdraw(2000)     # Invalid withdraw
# Out:
# Balance: 1000
# 500 deposited.
# Balance: 1500
# 300 withdrawn.
# Balance: 1200
# Insufficient balance

# %% [markdown]
# Ques - 5: Required Code

# %%
class Student:
    """This is a Student class used to demonstrate built-in attribution."""

    def __init__(self, name):
        self.name = name

print(Student.__name__)
print(Student.__doc__)
print(Student.__module__)
print(Student.__dict__)
# Out:
# Student
# This is a Student class used to demonstrate built-in attribution.
# __main__
# {'__module__': '__main__', '__firstlineno__': 1, '__doc__': 'This is a Student class used to demonstrate built-in attribution.', '__init__': <function Student.__init__ at 0x108e3f3d0>, '__static_attributes__': ('name',), '__dict__': <attribute '__dict__' of 'Student' objects>, '__weakref__': <attribute '__weakref__' of 'Student' objects>}

# %% [markdown]
# Ques - 6: Required Code

# %%
class Product:

    def __init__(self, name, price):
        self.name = name
        self.price = price

    def __str__(self):
        return f"Product: {self.name}, Price: {self.price}"
    
    def __add__(self,other):
        return self.price + other.price
    
    def __eq__ (self, other):
        return self.price == other.price
    
p1 = Product("Laptop", 50000)
p2 = Product("Phone", 30000)
p3 = Product("Tablet", 50000)

print(p1)
print(p1 + p2)
print(p1 == p3)
print(p1 == p2)
# Out:
# Product: Laptop, Price: 50000
# 80000
# True
# False
